# %% [markdown]
# # What is Programming?
#
# Programming is the simple act of writing instructions that the computer will execute.

# %% [markdown]
# The function print() in Python allows us to write messages on screen that are  shown to the users of the program.

# %%
print('welcome')
# Out:
# welcome

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# # In this workshop we will work using Google Colab.
# This is an example of how to make notes in google colab: double click over this text to start editing it.

# %% [markdown]
# #Arithmetic Operators
#
# An arithmetic operator takes two inputs, executes a calculation and returns the result of the operation.

# %% [markdown]
# # List of Operators
# - "+" ->	Addition of two operands 12 + 3 = 15
# - "-"	-> Substraction	12 - 3 = 9
# - "\*" ->	Multiplication	12 \* 3 = 36
# - "/"	-> Division	12 / 3 = 4
# - "%"	-> Modulus operation	16 % 3 = 1
# - "\**"	-> Exponentiation	12 \** 3 = 1728
# - "//" -> Executes Floor division	18 // 5 = 3

# %% [markdown]
# Estos son algunos ejemplos de operadores en matematicos en Python.

# %%
2 + 4 * 80
# Out:
# 322

# %%
(2+3) * 9
# Out:
# 45

# %%
30 * 10
# Out:
# 300

# %%
2 ** 8
# Out:
# 256

# %%
23 / 7
# Out:
# 3.2857142857142856

# %%
23 // 7
# Out:
# 3

# %%
9 % 2
# Out:
# 1

# %%
25 % 7
# Out:
# 4

# %% [markdown]
# # What are data types?
# In any high level programming language there is support for data types. Data types have sets of rules that define how they behave and what are their properties or characteristics.

# %% [markdown]
# ## Data types in Python
# - Text Type:	str
# - Numeric Types:	int, float, complex
# - Sequence Types:	list, tuple, range
#
# > Indented block

# %%
'Rick' + ' '+'Pepe'
# Out:
# 'Rick Pepe'

# %%
'Rick' + 12
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-d06c38203cb4> in <module>()
# ----> 1 'Rick' + 12
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# # ¿What happened with this code?
#
# Errors are part of programming. Python includes precise error messages that inform even the line of our program that contains an error.
#
# In this case, the error message says "can only concatenate str (not "int") to str". This tells us that the error is the type of data we're using, because it is not possible to add text and an integer number.
#
# Now we can see a text operation and integer numbers that is allowed in Python.

# %%
'Rick' * 5
# Out:
# 'RickRickRickRickRick'

# %%
'Rick' * 'Joe'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-b980620a7278> in <module>()
# ----> 1 'Rick' * 'Joe'
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %% [markdown]
# Additionally, COLAB offers help for error handling that allowes us to query StackOverflow. This is a website for questions and answers dedicated to programming where we can find a large amount  of users. It is possible to find help from users or others who have seen and solved the same errors.
#
# You can test this functionality by clicking the "SEARCH STACK OVERFLOW".

# %%
# Within Python it is possible to add notes or comments using the character #

# My program says Hi and asks for your name

print('Hello world!')
print('What is your name?')

# Now we create a variable that will store the name of the user
# Variables allow us to store data within python that can be used in our program.
# For our first program we create a variable called 'my_name' which will store the result of the input() function.
# The input() function allows the user to enter data into the program.


my_name = input()  
print('Nice to meet you, ' + my_name)
print('Your name has ',len(my_name),' letters') # The len() function calculates the amount of character within the object we specify as parameter. 

#We will see more about functions soon, and we'll create our own.

print('how old are you?')
my_age = input()

# To "cast" is the action of changing the data type of an object in order to do allowed operations within the program.
# in this case we want to add 1 to the age of our user.
# The input() function we used stored a text in the my_age variable. To add 1 to it we need to change my_age to a number.
# Lastly we can change the new number into a String so we can concatenate it to our text.

print('You will be ' + str(int(my_age)+1) + ' next year!')
# Out:
# Hello world!
# What is your name?
# Arki
# Nice to meet you, Arki
# Your name has  4  letters
# how old are you?
# 20
# You will be 21 next year!

# %% [markdown]
# # Boolean type and Binary Boolean Operators
#
# A Boolean is a data type with a single value: True or False.
# They can be used to control the flow of our program (more on this in the next class). We get boolean values when we use **comparative operators**.
#
# * This is a list of comparative operators in Python:
#
# ![image.png](data:image/png;base64,...)
#
# Image from the book from Al Sweigart, "Automate the boring stuff with Python"

# %%
# We can compare values and get a Boolean as result
42 == 42
# Out:
# True

# %%
42 == 65
# Out:
# False

# %%
'dog' != 'cat'
# Out:
# True

# %%
# The symbol = is used to assign a value to a variable. It is not an operator, like == is
age = 30
age == 30
# Out:
# True

# %% [markdown]
# ## Binary Booleans
#
# Binary booleans are operators that use booleans to evaluate two statements and define the result of the boolean. These operators are 'and', 'not' and 'or'.

# %%
# Binary Boolean help us to evaluate multiple statements.
# We can add a message if the name is outside a range.
# 
import random

guess_number = input('Guess a number from 1 to 5: ') # User entry
winning_number = random.randint(1, 5) # variable with the winning number

if guess_number == str(winning_number):
    print('Congratulations, you guessed right!') # Mensaje al ganador
elif int(guess_number) >= 6 or int(guess_number) <= 0:  
        print('Please read the instructions and try again.') # message for number out of range
else:print('The winning number was {}'.format(winning_number))
# Out:
# Guess a number from 1 to 5: 2
# Congratulations, you guessed right!

# %%
# Operaciones con operadores binarios
(4 < 5) and (5 < 6)

# %%
(4 < 5) and (9 < 6)

# %%
(1 == 2) or (2 == 2)

# %%
2 + 2 == 4 and not 2 + 2 == 5 and 2 * 2 == 2 + 2

# %% [markdown]
# #.format()
#
# With the format variable we can write variables within a string using brackets {} as containers for the result.

# %%
# from Python 3
i = 3.543546
print('Test string print: {}'.format(i))

# newer form in Python 3.6+
print(f'Second test string print: {i}')

# More than one variable
apples = 2
oranges = 4

print('I have {} apples and you have {} oranges.'.format(apples, oranges)) # We can add multiple variables by separating them with ,
# Out:
# Test string print: 3.543546
# Second test string print: 3.543546
# I have 2 apples and you have 4 oranges.

# %% [markdown]
# ## String Literals

# %%
# MORE VARIABLES!!!
var1='Hello,'
var2='is'
var3='my'
var4='Dave'
var5='name'
my_date= '2022-07-25'
print('Third test string print: {} {} {} {} {} and today is {}'.format(var1,var3,var5,var2,var4, my_date))
print(f'Third test string print: {var1} {var3} {var5} {var2} {var4} and today is {my_date}')
# Out:
# Third test string print: Hello, my name is Dave and today is 2022-07-25
# Third test string print: Hello, my name is Dave and today is 2022-07-25

# %% [markdown]
# # Important things to learn from the last example:
#
#
# *   Use descriptive variable names
# *   When writing it, think of making it understandatable for someone else (your future self will thank you)
# *   Use comments!
